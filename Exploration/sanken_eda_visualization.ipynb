# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# Style and format preferences

# Apply the Seaborn style
plt.style.use('seaborn-v0_8-deep')
# Disable scientific notation
pd.options.display.float_format = '{:.0f}'.format

# %%
# Read CSV without initial date parsing
df = pd.read_csv('master_transaksi.csv')

# List of date columns to enforce conversion with errors='coerce'
date_columns = ['order_req', 'order_sent']

# Apply pd.to_datetime with errors='coerce' to each date column
for col in date_columns:
    df[col] = pd.to_datetime(df[col], errors='coerce', format="%Y-%m-%d")

# %%
df.head(5)
# Out:
#           orderID order_sent         custName  order_req type  productName  \
# 0  TRXINV1G1O0044 2016-01-05  A L F A - DEPOK 2016-01-05   DO      HWD-766
# 1  TRXINV1G1O0046 2016-01-05  A L F A - DEPOK 2016-01-05   DO   SK-P170-SL
# 2  TRXINV1G1O0046 2016-01-05  A L F A - DEPOK 2016-01-05   DO  SK-G256H-BK
# 3  TRXINV1G1O0046 2016-01-05  A L F A - DEPOK 2016-01-05   DO       SK-350
# 4  TRXINV1G1O0045 2016-01-05  A L F A - DEPOK 2016-01-05   DO    HWD-773SH
#
#    sales  perprice  qty  qty_req
# 0  1HER2   1549000    5        5
# 1  1HER2   1641000    2        2
# 2  1HER2   3226000    2        2
# 3  1HER2   4121000    2        2
# 4  1HER2   1564000    5        5

# %%
df['totalprice'] = df['qty'] * df['perprice']

# Aggregate monthly metrics grouped by purchase month
monthly_summary = df.groupby(df['order_req'].dt.to_period('M').rename('purchase_month')).agg(
    sales_total=('totalprice', 'sum'),
    sales_average=('totalprice', 'mean'),
    orders_total=('orderID', 'count')
)

# Calculate the growth rate for each metric
monthly_summary['sales_growth_rate'] = monthly_summary['sales_total'].pct_change() * 100
monthly_summary['aov_growth_rate'] = monthly_summary['sales_average'].pct_change() * 100
monthly_summary['order_growth_rate'] = monthly_summary['orders_total'].pct_change() * 100

# Fill NaN values with 0, round, and convert to integers
monthly_summary = monthly_summary.fillna(0).round(2)

# Apply background gradient to the growth columns with a custom colormap
styled_summary = monthly_summary.style.format("{:,}")  # Apply comma formatting
styled_summary = styled_summary.background_gradient(
    subset=['sales_growth_rate', 'aov_growth_rate', 'order_growth_rate'],
    cmap="RdYlGn",  # Red to Yellow to Green colormap
    vmin=-100,      # Set minimum for orange on the left end
    vmax=100        # Set maximum for green on the right end
)

# Display the styled DataFrame
styled_summary
# Out:
# <style type="text/css">
# #T_72767_row0_col3, #T_72767_row0_col4, #T_72767_row0_col5, #T_72767_row26_col4, #T_72767_row36_col3 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_72767_row1_col3 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_72767_row1_col4, #T_72767_row7_col3, #T_72767_row14_col5, #T_72767_row21_col3 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_72767_row1_col5 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_72767_row2_col3, #T_72767_row23_col5, #T_72767_row31_col5, #T_72767_row35_col5, #T_72767_row43_col5 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_72767_row2_col4, #T_72767_row41_col4, #T_72767_row44_col5, #T_72767_row46_col5, #T_72767_row47_col4 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_72767_row2_col5, #T_72767_row48_col5 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_72767_row3_col3 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_72767_row3_col4, #T_72767_row14_col4, #T_72767_row55_col5 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_72767_row3_col5 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_72767_row4_col3 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_72767_row4_col4, #T_72767_row38_col3 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_72767_row4_col5, #T_72767_row40_col4, #T_72767_row58_col4 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_72767_row5_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_72767_row5_col4 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_72767_row5_col5, #T_72767_row12_col3 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_72767_row6_col3 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_72767_row6_col4, #T_72767_row20_col4, #T_72767_row35_col4 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_72767_row6_col5 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_72767_row7_col4, #T_72767_row44_col3, #T_72767_row59_col3 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_72767_row7_col5, #T_72767_row33_col5 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_72767_row8_col3, #T_72767_row11_col4, #T_72767_row22_col5, #T_72767_row24_col5, #T_72767_row27_col3 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_72767_row8_col4, #T_72767_row24_col3, #T_72767_row28_col5, #T_72767_row45_col4 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_72767_row8_col5, #T_72767_row21_col5, #T_72767_row44_col4, #T_72767_row58_col3 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_72767_row9_col3, #T_72767_row48_col3 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_72767_row9_col4, #T_72767_row54_col5 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_72767_row9_col5, #T_72767_row27_col5, #T_72767_row43_col3, #T_72767_row52_col5 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_72767_row10_col3 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_72767_row10_col4, #T_72767_row39_col3 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_72767_row10_col5, #T_72767_row14_col3, #T_72767_row20_col3, #T_72767_row52_col3 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_72767_row11_col3 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_72767_row11_col5 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_72767_row12_col4, #T_72767_row32_col5 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_72767_row12_col5 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_72767_row13_col3 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_72767_row13_col4 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_72767_row13_col5, #T_72767_row45_col5 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_72767_row15_col3 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_72767_row15_col4, #T_72767_row33_col4, #T_72767_row59_col4 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_72767_row15_col5 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_72767_row16_col3 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_72767_row16_col4, #T_72767_row32_col4, #T_72767_row36_col5, #T_72767_row37_col3, #T_72767_row39_col4 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_72767_row16_col5, #T_72767_row34_col5, #T_72767_row57_col5 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_72767_row17_col3 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_72767_row17_col4, #T_72767_row31_col3 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_72767_row17_col5 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_72767_row18_col3, #T_72767_row18_col5 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_72767_row18_col4, #T_72767_row46_col4 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_72767_row19_col3, #T_72767_row56_col5 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_72767_row19_col4 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_72767_row19_col5 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_72767_row20_col5, #T_72767_row24_col4, #T_72767_row31_col4, #T_72767_row58_col5 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_72767_row21_col4, #T_72767_row22_col4, #T_72767_row34_col3 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_72767_row22_col3 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_72767_row23_col3, #T_72767_row29_col4, #T_72767_row32_col3 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_72767_row23_col4, #T_72767_row54_col4, #T_72767_row56_col4 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_72767_row25_col3 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_72767_row25_col4 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_72767_row25_col5 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_72767_row26_col3 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_72767_row26_col5 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_72767_row27_col4, #T_72767_row43_col4 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_72767_row28_col3 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_72767_row28_col4, #T_72767_row57_col3 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_72767_row29_col3 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_72767_row29_col5 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_72767_row30_col3 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_72767_row30_col4, #T_72767_row37_col5, #T_72767_row38_col5, #T_72767_row51_col5, #T_72767_row53_col4 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_72767_row30_col5 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_72767_row33_col3 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_72767_row34_col4, #T_72767_row37_col4, #T_72767_row55_col4 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_72767_row35_col3 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_72767_row36_col4, #T_72767_row40_col3 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_72767_row38_col4 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_72767_row39_col5 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_72767_row40_col5 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_72767_row41_col3 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_72767_row41_col5, #T_72767_row59_col5 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_72767_row42_col3 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_72767_row42_col4 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_72767_row42_col5 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_72767_row45_col3 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_72767_row46_col3, #T_72767_row48_col4 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_72767_row47_col3 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_72767_row47_col5, #T_72767_row50_col4 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_72767_row49_col3, #T_72767_row50_col3, #T_72767_row56_col3 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_72767_row49_col4, #T_72767_row49_col5 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_72767_row50_col5 {
#   background-color: #ddf191;
#   color: #0000

# %%
# Extract year and month from the date i
monthly_summary['year'] = monthly_summary.index.year
monthly_summary['month'] = monthly_summary.index.month

# Set up the figure with a 2x3 grid: 3 line charts and 3 heatmaps
fig, axes = plt.subplots(2, 3, figsize=(18, 8), sharex='col', gridspec_kw={'height_ratios': [2, 1]})

# Define colors for each year
years = monthly_summary['year'].unique()
colors = plt.cm.tab10(np.arange(len(years)))  # Use tab10 colormap for consistent color assignment; current style is too dark

# Metrics to plot
metrics = ['sales_total', 'sales_average', 'orders_total']
titles = ['Total Sales by Month', 'Average Order Value (AOV) by Month', 'Total Orders by Month']
y_labels = ['Total Sales (Rp)', 'Average Order Value (Rp)', 'Total Orders']
growth_metrics = ['sales_growth_rate', 'aov_growth_rate', 'order_growth_rate']
growth_titles = ['Sales Growth Rate (%)', 'AOV Growth Rate (%)', 'Order Growth Rate (%)']

# Plot line charts for each metric
for i, (metric, title, y_label) in enumerate(zip(metrics, titles, y_labels)):
    for j, year in enumerate(years):
        yearly_data = monthly_summary[monthly_summary['year'] == year]
        axes[0, i].plot(yearly_data['month'], yearly_data[metric], label=f'{year}', color=colors[j], linewidth=2)
    axes[0, i].set_title(title)
    axes[0, i].set_ylabel(y_label)
    axes[0, i].set_xticks(range(1, 13))
    axes[0, i].set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
    if i == 0:
        axes[0, i].legend(title='Year', loc='upper left')

# Prepare and plot heatmaps for growth rates
for i, (growth_metric, growth_title) in enumerate(zip(growth_metrics, growth_titles)):
    growth_data = monthly_summary.pivot_table(index='year', columns='month', values=growth_metric)
    sns.heatmap(growth_data, cmap='RdYlGn', ax=axes[1, i], cbar=False, annot=True, fmt=".1f", center=0)
    axes[1, i].set_title(growth_title)
    axes[1, i].set_xticks(np.arange(0.5, 12))
    axes[1, i].set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
    axes[1, i].set_xlabel('Month')

# Final layout adjustments
plt.suptitle('Monthly Metrics and Growth Rates by Year', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# Aggregation for each product with inline calculations for percentages

product_performance = df.groupby('productName').agg(
    total_revenue=('totalprice', 'sum'),
    total_revenue_pct=('totalprice', lambda x: x.sum() / df['totalprice'].sum() * 100),
    aov=('totalprice', 'mean'),
    order_count=('orderID', 'count'),
    order_count_pct=('orderID', lambda x: x.count() / df['orderID'].count() * 100)
)

# Sort by Total Revenue in descending order
product_performance = product_performance.sort_values(by='total_revenue', ascending=False)

# Round values to two decimal places
product_performance = product_performance.round(2)

# Apply background gradients and comma formatting
styled_product_performance = product_performance.style.format("{:,.2f}").background_gradient(
    subset=['aov', 'total_revenue_pct', 'order_count_pct'],
    cmap="Greens",
    vmin=0
)

# Display the styled DataFrame
styled_product_performance
# Out:
# <style type="text/css">
# #T_44e48_row0_col1, #T_44e48_row3_col4, #T_44e48_row151_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_44e48_row0_col2, #T_44e48_row1_col2, #T_44e48_row9_col2, #T_44e48_row12_col2, #T_44e48_row14_col2, #T_44e48_row15_col2, #T_44e48_row17_col2, #T_44e48_row21_col2, #T_44e48_row26_col2, #T_44e48_row34_col2, #T_44e48_row36_col2, #T_44e48_row41_col2, #T_44e48_row46_col2, #T_44e48_row49_col2, #T_44e48_row50_col2, #T_44e48_row57_col2, #T_44e48_row58_col2, #T_44e48_row60_col2, #T_44e48_row66_col2, #T_44e48_row69_col2, #T_44e48_row70_col2, #T_44e48_row75_col2, #T_44e48_row79_col2, #T_44e48_row83_col2, #T_44e48_row88_col4, #T_44e48_row94_col4, #T_44e48_row99_col2, #T_44e48_row100_col2, #T_44e48_row109_col2, #T_44e48_row109_col4, #T_44e48_row118_col2, #T_44e48_row120_col4, #T_44e48_row126_col4, #T_44e48_row128_col1, #T_44e48_row129_col1, #T_44e48_row130_col1, #T_44e48_row137_col4, #T_44e48_row139_col4, #T_44e48_row157_col4, #T_44e48_row175_col4, #T_44e48_row185_col2, #T_44e48_row196_col4, #T_44e48_row250_col2, #T_44e48_row264_col2, #T_44e48_row280_col2, #T_44e48_row338_col2, #T_44e48_row356_col2, #T_44e48_row385_col2, #T_44e48_row415_col2, #T_44e48_row417_col2 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_44e48_row0_col4 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_44e48_row1_col1 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# #T_44e48_row1_col4 {
#   background-color: #258d47;
#   color: #f1f1f1;
# }
# #T_44e48_row2_col1 {
#   background-color: #006227;
#   color: #f1f1f1;
# }
# #T_44e48_row2_col2, #T_44e48_row67_col2, #T_44e48_row71_col2, #T_44e48_row72_col4, #T_44e48_row78_col2, #T_44e48_row88_col2, #T_44e48_row105_col1, #T_44e48_row105_col2, #T_44e48_row106_col1, #T_44e48_row107_col1, #T_44e48_row107_col4, #T_44e48_row108_col1, #T_44e48_row109_col1, #T_44e48_row110_col1, #T_44e48_row133_col4, #T_44e48_row149_col4, #T_44e48_row152_col4 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_44e48_row2_col4 {
#   background-color: #62bb6d;
#   color: #f1f1f1;
# }
# #T_44e48_row3_col1 {
#   background-color: #097532;
#   color: #f1f1f1;
# }
# #T_44e48_row3_col2, #T_44e48_row6_col2, #T_44e48_row76_col2, #T_44e48_row108_col2, #T_44e48_row116_col2, #T_44e48_row123_col4, #T_44e48_row130_col2, #T_44e48_row138_col2, #T_44e48_row160_col4, #T_44e48_row162_col4, #T_44e48_row176_col1, #T_44e48_row176_col4, #T_44e48_row177_col1, #T_44e48_row178_col1, #T_44e48_row179_col1, #T_44e48_row180_col1, #T_44e48_row181_col1, #T_44e48_row182_col1, #T_44e48_row182_col4, #T_44e48_row183_col1, #T_44e48_row184_col1, #T_44e48_row186_col2, #T_44e48_row203_col2, #T_44e48_row206_col2, #T_44e48_row228_col4, #T_44e48_row230_col4, #T_44e48_row236_col4, #T_44e48_row238_col2, #T_44e48_row274_col2, #T_44e48_row289_col2, #T_44e48_row364_col2, #T_44e48_row406_col2 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_44e48_row4_col1 {
#   background-color: #0a7633;
#   color: #f1f1f1;
# }
# #T_44e48_row4_col2, #T_44e48_row44_col2, #T_44e48_row63_col4, #T_44e48_row75_col4, #T_44e48_row79_col4, #T_44e48_row92_col1, #T_44e48_row93_col1, #T_44e48_row94_col1, #T_44e48_row95_col1, #T_44e48_row127_col4, #T_44e48_row169_col4, #T_44e48_row272_col2, #T_44e48_row318_col2, #T_44e48_row395_col2 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_44e48_row4_col4, #T_44e48_row16_col4 {
#   background-color: #9bd696;
#   color: #000000;
# }
# #T_44e48_row5_col1 {
#   background-color: #16803c;
#   color: #f1f1f1;
# }
# #T_44e48_row5_col2, #T_44e48_row31_col2, #T_44e48_row64_col2, #T_44e48_row86_col4, #T_44e48_row106_col4, #T_44e48_row117_col1, #T_44e48_row118_col1, #T_44e48_row119_col1, #T_44e48_row120_col1, #T_44e48_row121_col1, #T_44e48_row125_col4, #T_44e48_row131_col4, #T_44e48_row143_col4, #T_44e48_row167_col2, #T_44e48_row241_col2, #T_44e48_row344_col2, #T_44e48_row408_col2 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_44e48_row5_col4 {
#   background-color: #70c274;
#   color: #000000;
# }
# #T_44e48_row6_col1 {
#   background-color: #208843;
#   color: #f1f1f1;
# }
# #T_44e48_row6_col4 {
#   background-color: #006428;
#   color: #f1f1f1;
# }
# #T_44e48_row7_col1 {
#   background-color: #3aa357;
#   color: #f1f1f1;
# }
# #T_44e48_row7_col2, #T_44e48_row18_col2, #T_44e48_row27_col2, #T_44e48_row28_col2, #T_44e48_row42_col2, #T_44e48_row55_col2, #T_44e48_row101_col2, #T_44e48_row112_col2, #T_44e48_row144_col2, #T_44e48_row147_col2, #T_44e48_row154_col2, #T_44e48_row158_col1, #T_44e48_row159_col1, #T_44e48_row160_col1, #T_44e48_row161_col1, #T_44e48_row162_col1, #T_44e48_row163_col1, #T_44e48_row164_col1, #T_44e48_row165_col2, #T_44e48_row165_col4, #T_44e48_row176_col2, #T_44e48_row182_col2, #T_44e48_row186_col4, #T_44e48_row205_col2, #T_44e48_row210_col2, #T_44e48_row217_col4, #T_44e48_row222_col2, #T_44e48_row248_col2, #T_44e48_row309_col4, #T_44e48_row330_col2, #T_44e48_row337_col2, #T_44e48_row396_col2, #T_44e48_row398_col2, #T_44e48_row399_col2, #T_44e48_row424_col2 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_44e48_row7_col4 {
#   background-color: #39a257;
#   color: #f1f1f1;
# }
# #T_44e48_row8_col1 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_44e48_row8_col2, #T_44e48_row38_col2, #T_44e48_row65_col2, #T_44e48_row74_col2, #T_44e48_row86_col2, #T_44e48_row121_col2, #T_44e48_row164_col4, #T_44e48_row173_col4, #T_44e48_row187_col2, #T_44e48_row209_col2, #T_44e48_row234_col4, #T_44e48_row244_col4, #T_44e48_row278_col2, #T_44e48_row354_col2, #T_44e48_row380_col2 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_44e48_row8_col4 {
#   background-color: #86cc85;
#   color: #000000;
# }
# #T_44e48_row9_col1, #T_44e48_row10_col1 {
#   background-color: #60ba6c;
#   color: #f1f1f1;
# }
# #T_44e48_row9_col4 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_44e48_row10_col2, #T_44e48_row22_col2, #T_44e48_row24_col2, #T_44e48_row25_col2, #T_44e48_row37_col2, #T_44e48_row52_col2, #T_44e48_row63_col2, #T_44e48_row77_col2, #T_44e48_row81_col2, #T_44e48_row94_col2, #T_44e48_row99_col4, #T_44e48_row100_col4, #T_44e48_row113_col4, #T_44e48_row117_col2, #T_44e48_row119_col4, #T_44e48_row122_col1, #T_44e48_row123_col1, #T_44e48_row124_col1, #T_44e48_row125_col1, #T_44e48_row126_col1, #T_44e48_row127_col1, #T_44e48_row130_col4, #T_44e48_row138_col4, #T_44e48_row140_col4, #T_44e48_row141_col4, #T_44e48_row155_col4, #T_44e48_row200_col2, #T_44e48_row207_col2, #T_44e48_row231_col4, #T_44e48_row246_col2, #T_44e48_row262_col2, #T_44e48_row311_col2, #T_44e48_row326_col2, #T_44e48_row346_col2, #T_44e48_row347_col2, #T_44e48_row350_col2, #T_44e48_row351_col2, #T_44e48_row377_col2, #T_44e48_row410_col2, #T_44e48_row411_col2 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_44e48_row10_col4 {
#   background-color: #a0d99b;
#   color: #000000;
# }
# #T_44e48_row11_col1 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_44e48_row11_col2, #T_44e48_row20_col2, #T_44e48_row39_col2, #T_44e48_row78_col4, #T_44e48_row98_col4, #T_44e48_row104_col4, #T_44e48_row111_col1, #T_44e48_row112_col1, #T_44e48_row113_col1, #T_44e48_row114_col1, #T_44e48_row115_col1, #T_44e48_row116_col1, #T_44e48_row129_col4, #T_44e48_row211_col2, #T_44e48_row239_col4, #T_44e48_row249_col2, #T_44e48_row341_col2 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_44e48_row11_col4, #T_44e48_row31_col1, #T_44e48_row48_col4 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_44e48_row12_col1 {
#   background-color: #76c578;
#   color: #000000;
# }
# #T_44e48_row12_col4, #T_44e48_row22_col1, #T_44e48_row61_col4 {
#   background-color: #9cd797;
#   color: #000000;
# }
# #T_44e48_row13_col1, #T_44e48_row14_col1, #T_44e48_row15_col1 {
#   background-color: #83cb82;
#   color: #000000;
# }
# #T_44e48_row13_col2, #T_44e48_row68_col2, #T_44e48_row73_col2, #T_44e48_row80_col2, #T_44e48_row98_col2, #T_44e48_row118_col4, #T_44e48_row120_col2, #T_44e48_row126_col2, #T_44e48_row131_col1, #T_44e48_row132_col1, #T_44e48_row132_col2, #T_44e48_row133_col1, #T_44e48_row134_col1, #T_44e48_row134_col4, #T_44e48_row135_col1, #T_44e48_row135_col4, #T_44e48_row136_col1, #T_44e48_row137_col1, #T_44e48_row138_col1, #T_44e48_row139_col

# %%
# Read CSV containing all products' data
df1 = pd.read_csv('master_produk.csv')

# Drop redundant/unnecessary columns
df1 = df1.drop(columns=['qty', 'price'])

# %%
# Merge transaction table (master_transaksi) and product table (master_produk)
df_itemsales = pd.merge(df, df1, how='inner', on='productName')

# %%
df_itemsales.head(5)
# Out:
#           orderID order_sent                        custName  order_req type  \
# 0  TRXINV1G1O0044 2016-01-05                 A L F A - DEPOK 2016-01-05   DO
# 1  TRXINV1G2O0975 2016-02-27                 A L F A - DEPOK 2016-02-24   DO
# 2  TRXINVCH400009 2017-04-19                      AGUNG JAYA 2017-04-10   DO
# 3  TRXINV1G1O0046 2016-01-05                 A L F A - DEPOK 2016-01-05   DO
# 4  TRXINV5G1O0042 2016-01-15  METRO - PURBALINGGA"" KMET01"" 2016-01-12   DO
#
#   productName  sales  perprice  qty  qty_req  totalprice  itemID  \
# 0     HWD-766  1HER2   1549000    5        5     7745000       2
# 1     HWD-766  1HER2   1549000    5        5     7745000       2
# 2     HWD-766  CBERT   1454000    3        3     4362000       2
# 3  SK-P170-SL  1HER2   1641000    2        2     3282000       8
# 4  SK-P170-SL   5YUL   1675000   10       10    16750000       8
#
#           itemType
# 0  Water Dispenser
# 1  Water Dispenser
# 2  Water Dispenser
# 3     Refrigerator
# 4     Refrigerator

# %%
# Aggregation for each item type (refrigerator, washing machine, etc.) with inline calculations for percentages

product_performance = df_itemsales.groupby('itemType').agg(
    total_revenue=('totalprice', 'sum'),
    total_revenue_pct=('totalprice', lambda x: x.sum() / df_itemsales['totalprice'].sum() * 100),
    aov=('totalprice', 'mean'),
    order_count=('orderID', 'count'),
    order_count_pct=('orderID', lambda x: x.count() / df_itemsales['orderID'].count() * 100)
)

# Sort by Total Revenue in descending order
product_performance = product_performance.sort_values(by='total_revenue', ascending=False)

# Round values to two decimal places
product_performance = product_performance.round(2)

# Apply background gradients and comma formatting
styled_product_performance = product_performance.style.format("{:,.2f}").background_gradient(
    subset=['aov', 'total_revenue_pct', 'order_count_pct'],
    cmap="Greens", 
    vmin=0
)

# Display the styled DataFrame
styled_product_performance
# Out:
# <style type="text/css">
# #T_0ee44_row0_col1, #T_0ee44_row0_col4, #T_0ee44_row4_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_0ee44_row0_col2 {
#   background-color: #289049;
#   color: #f1f1f1;
# }
# #T_0ee44_row1_col1 {
#   background-color: #2e964d;
#   color: #f1f1f1;
# }
# #T_0ee44_row1_col2 {
#   background-color: #3ca559;
#   color: #f1f1f1;
# }
# #T_0ee44_row1_col4 {
#   background-color: #16803c;
#   color: #f1f1f1;
# }
# #T_0ee44_row2_col1 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_0ee44_row2_col2 {
#   background-color: #58b668;
#   color: #f1f1f1;
# }
# #T_0ee44_row2_col4 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# #T_0ee44_row3_col1 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_0ee44_row3_col2 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_0ee44_row3_col4 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_0ee44_row4_col1, #T_0ee44_row7_col4 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_0ee44_row4_col4 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_0ee44_row5_col1 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_0ee44_row5_col2 {
#   background-color: #66bd6f;
#   color: #f1f1f1;
# }
# #T_0ee44_row5_col4 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_0ee44_row6_col1, #T_0ee44_row6_col4, #T_0ee44_row7_col1, #T_0ee44_row8_col4, #T_0ee44_row9_col4, #T_0ee44_row10_col4 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_0ee44_row6_col2 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_0ee44_row7_col2 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_0ee44_row8_col1 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_0ee44_row8_col2 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_0ee44_row9_col1, #T_0ee44_row10_col1, #T_0ee44_row11_col1, #T_0ee44_row11_col4 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_0ee44_row9_col2 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_0ee44_row10_col2 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_0ee44_row11_col2 {
#   background-color: #aadda4;
#   color: #000000;
# }
# #T_0ee44_row12_col1, #T_0ee44_row12_col4, #T_0ee44_row13_col1, #T_0ee44_row13_col4, #T_0ee44_row14_col1, #T_0ee44_row14_col4 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_0ee44_row12_col2 {
#   background-color: #91d28e;
#   color: #000000;
# }
# #T_0ee44_row13_col2 {
#   background-color: #65bd6f;
#   color: #f1f1f1;
# }
# #T_0ee44_row14_col2 {
#   background-color: #d4eece;
#   color: #000000;
# }
# </style>
# <table id="T_0ee44">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0ee44_level0_col0" class="col_heading level0 col0" >total_revenue</th>
#       <th id="T_0ee44_level0_col1" class="col_heading level0 col1" >total_revenue_pct</th>
#       <th id="T_0ee44_level0_col2" class="col_heading level0 col2" >aov</th>
#       <th id="T_0ee44_level0_col3" class="col_heading level0 col3" >order_count</th>
#       <th id="T_0ee44_level0_col4" class="col_heading level0 col4" >order_count_pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >itemType</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ee44_level0_row0" class="row_heading level0 row0" >Refrigerator</th>
#       <td id="T_0ee44_row0_col0" class="data row0 col0" >38,487,328,025.00</td>
#       <td id="T_0ee44_row0_col1" class="data row0 col1" >42.15</td>
#       <td id="T_0ee44_row0_col2" class="data row0 col2" >6,257,084.71</td>
#       <td id="T_0ee44_row0_col3" class="data row0 col3" >6,151.00</td>
#       <td id="T_0ee44_row0_col4" class="data row0 col4" >35.44</td>
#     </tr>
#     <tr>
#       <th id="T_0ee44_level0_row1" class="row_heading level0 row1" >Washing Machine</th>
#       <td id="T_0ee44_row1_col0" class="data row1 col0" >27,151,595,485.00</td>
#       <td id="T_0ee44_row1_col1" class="data row1 col1" >29.74</td>
#       <td id="T_0ee44_row1_col2" class="data row1 col2" >5,562,711.63</td>
#       <td id="T_0ee44_row1_col3" class="data row1 col3" >4,881.00</td>
#       <td id="T_0ee44_row1_col4" class="data row1 col4" >28.12</td>
#     </tr>
#     <tr>
#       <th id="T_0ee44_level0_row2" class="row_heading level0 row2" >Water Dispenser</th>
#       <td id="T_0ee44_row2_col0" class="data row2 col0" >9,321,859,042.00</td>
#       <td id="T_0ee44_row2_col1" class="data row2 col1" >10.21</td>
#       <td id="T_0ee44_row2_col2" class="data row2 col2" >4,865,270.90</td>
#       <td id="T_0ee44_row2_col3" class="data row2 col3" >1,916.00</td>
#       <td id="T_0ee44_row2_col4" class="data row2 col4" >11.04</td>
#     </tr>
#     <tr>
#       <th id="T_0ee44_level0_row3" class="row_heading level0 row3" >Rice Cooker</th>
#       <td id="T_0ee44_row3_col0" class="data row3 col0" >5,354,192,175.00</td>
#       <td id="T_0ee44_row3_col1" class="data row3 col1" >5.86</td>
#       <td id="T_0ee44_row3_col2" class="data row3 col2" >2,851,007.55</td>
#       <td id="T_0ee44_row3_col3" class="data row3 col3" >1,878.00</td>
#       <td id="T_0ee44_row3_col4" class="data row3 col4" >10.82</td>
#     </tr>
#     <tr>
#       <th id="T_0ee44_level0_row4" class="row_heading level0 row4" >Microphone</th>
#       <td id="T_0ee44_row4_col0" class="data row4 col0" >2,927,634,454.00</td>
#       <td id="T_0ee44_row4_col1" class="data row4 col1" >3.21</td>
#       <td id="T_0ee44_row4_col2" class="data row4 col2" >8,585,438.28</td>
#       <td id="T_0ee44_row4_col3" class="data row4 col3" >341.00</td>
#       <td id="T_0ee44_row4_col4" class="data row4 col4" >1.96</td>
#     </tr>
#     <tr>
#       <th id="T_0ee44_level0_row5" class="row_heading level0 row5" >Speaker</th>
#       <td id="T_0ee44_row5_col0" class="data row5 col0" >2,690,828,868.00</td>
#       <td id="T_0ee44_row5_col1" class="data row5 col1" >2.95</td>
#       <td id="T_0ee44_row5_col2" class="data row5 col2" >4,591,858.14</td>
#       <td id="T_0ee44_row5_col3" class="data row5 col3" >586.00</td>
#       <td id="T_0ee44_row5_col4" class="data row5 col4" >3.38</td>
#     </tr>
#     <tr>
#       <th id="T_0ee44_level0_row6" class="row_heading level0 row6" >TV</th>
#       <td id="T_0ee44_row6_col0" class="data row6 col0" >1,614,998,072.00</td>
#       <td id="T_0ee44_row6_col1" class="data row6 col1" >1.77</td>
#       <td id="T_0ee44_row6_col2" class="data row6 col2" >6,459,992.29</td>
#       <td id="T_0ee44_row6_col3" class="data row6 col3" >250.00</td>
#       <td id="T_0ee44_row6_col4" class="data row6 col4" >1.44</td>
#     </tr>
#     <tr>
#       <th id="T_0ee44_level0_row7" class="row_heading level0 row7" >Gas Stove</th>
#       <td id="T_0ee44_row7_col0" class="data row7 col0" >1,540,148,742.00</td>
#       <td id="T_0ee44_row7_col1" class="data row7 col1" >1.69</td>
#       <td id="T_0ee44_row7_col2" class="data row7 col2" >3,086,470.42</td>
#       <td id="T_0ee44_row7_col3" class="data row7 col3" >499.00</td>
#       <td id="T_0ee44_row7_col4" class="data row7 col4" >2.88</td>
#     </tr>
#     <tr>
#       <th id="T_0ee44_level0_row8" class="row_heading level0 row8" >AC</th>
#       <td id="T_0ee44_row8_col0" class="data row8 col0" >1,157,375,072.00</td>
#       <td id="T_0ee44_row8_col1" class="data row8 col1" >1.27</td>
#       <td id="T_0ee44_row8_col2" class="data row8 col2" >4,538,725.77</td>
#       <td id="T_0ee44_row8_col3" class="data row8 col3" >255.00</td>
#       <td id="T_0ee44_row8_col4" class="data row8 col4" >1.47</td>
#     </tr>
#     <tr>
#       <th id="T_0ee44_level0_row9" class="row_heading level0 row9" >Fan</th>
#       <td id="T_0ee44_row9_col0" class="data row9 col0" >425,169,752.00</td>
#       <td id="T_0ee44_row9_col1" class="data row9 col1" >0.47</td>
#       <td id="T_0ee44_row9_col2" class="data row9 col2" >1,629,002.88</td>
#       <td id="T_0ee44_row9_col3" class="data row9 col3" >261.00</td>
#       <td id="T_0ee44_row9_col4" class="data row9 col4" >1.50</td>
#     </tr>
#     <tr>
#       <th id="T_0ee44_level0_row10" class="row_heading level0 row10" >Iron</th>
#       <td id="T_0ee44_row10_col0" class="data row10 col0" >345,655,596.00</td>
#       <td

# %%
df.head(5)
# Out:
#           orderID order_sent         custName  order_req type  productName  \
# 0  TRXINV1G1O0044 2016-01-05  A L F A - DEPOK 2016-01-05   DO      HWD-766
# 1  TRXINV1G1O0046 2016-01-05  A L F A - DEPOK 2016-01-05   DO   SK-P170-SL
# 2  TRXINV1G1O0046 2016-01-05  A L F A - DEPOK 2016-01-05   DO  SK-G256H-BK
# 3  TRXINV1G1O0046 2016-01-05  A L F A - DEPOK 2016-01-05   DO       SK-350
# 4  TRXINV1G1O0045 2016-01-05  A L F A - DEPOK 2016-01-05   DO    HWD-773SH
#
#    sales  perprice  qty  qty_req
# 0  1HER2   1549000    5        5
# 1  1HER2   1641000    2        2
# 2  1HER2   3226000    2        2
# 3  1HER2   4121000    2        2
# 4  1HER2   1564000    5        5

# %%
# Extract the year from the 'order_req' column and assign it to a new column 'purchase_year'
df['purchase_year'] = pd.to_datetime(df['order_req']).dt.year

# Group by customer_id and purchase_year, and calculate order_count
customer_orders = (
    df.groupby(['custName', 'purchase_year'])
    .size()
    .reset_index(name='order_count')
)

# Group by purchase_year to calculate unique_customers and repeat_customers
summary = (
    customer_orders.groupby('purchase_year')
    .agg(
        unique_customers=('custName', 'nunique'),
        repeat_customers=('order_count', lambda x: (x >= 2).sum())
    )
    .reset_index()
)

# Calculate repeat_rate
summary['repeat_rate'] = (summary['repeat_customers'] / summary['unique_customers'] * 100).round(2)

# Display the summary sorted by purchase_year
summary = summary.sort_values('purchase_year')

styled_summary = summary.style.format("{:,.2f}", subset=['repeat_rate']).set_table_styles(
    [{
        'selector': 'table',
        'props': [('border', '1px solid black'), ('border-collapse', 'collapse')]
    }, {
        'selector': 'th, td',
        'props': [('border', '1px solid black'), ('padding', '8px')]
    }]
)

# Display the styled table
styled_summary
# Out:
# <style type="text/css">
# #T_28e58 table {
#   border: 1px solid black;
#   border-collapse: collapse;
# }
# #T_28e58 th {
#   border: 1px solid black;
#   padding: 8px;
# }
# #T_28e58  td {
#   border: 1px solid black;
#   padding: 8px;
# }
# </style>
# <table id="T_28e58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28e58_level0_col0" class="col_heading level0 col0" >purchase_year</th>
#       <th id="T_28e58_level0_col1" class="col_heading level0 col1" >unique_customers</th>
#       <th id="T_28e58_level0_col2" class="col_heading level0 col2" >repeat_customers</th>
#       <th id="T_28e58_level0_col3" class="col_heading level0 col3" >repeat_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28e58_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_28e58_row0_col0" class="data row0 col0" >2016</td>
#       <td id="T_28e58_row0_col1" class="data row0 col1" >46</td>
#       <td id="T_28e58_row0_col2" class="data row0 col2" >43</td>
#       <td id="T_28e58_row0_col3" class="data row0 col3" >93.48</td>
#     </tr>
#     <tr>
#       <th id="T_28e58_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_28e58_row1_col0" class="data row1 col0" >2017</td>
#       <td id="T_28e58_row1_col1" class="data row1 col1" >108</td>
#       <td id="T_28e58_row1_col2" class="data row1 col2" >90</td>
#       <td id="T_28e58_row1_col3" class="data row1 col3" >83.33</td>
#     </tr>
#     <tr>
#       <th id="T_28e58_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_28e58_row2_col0" class="data row2 col0" >2018</td>
#       <td id="T_28e58_row2_col1" class="data row2 col1" >120</td>
#       <td id="T_28e58_row2_col2" class="data row2 col2" >94</td>
#       <td id="T_28e58_row2_col3" class="data row2 col3" >78.33</td>
#     </tr>
#     <tr>
#       <th id="T_28e58_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_28e58_row3_col0" class="data row3 col0" >2019</td>
#       <td id="T_28e58_row3_col1" class="data row3 col1" >116</td>
#       <td id="T_28e58_row3_col2" class="data row3 col2" >104</td>
#       <td id="T_28e58_row3_col3" class="data row3 col3" >89.66</td>
#     </tr>
#     <tr>
#       <th id="T_28e58_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_28e58_row4_col0" class="data row4 col0" >2020</td>
#       <td id="T_28e58_row4_col1" class="data row4 col1" >90</td>
#       <td id="T_28e58_row4_col2" class="data row4 col2" >79</td>
#       <td id="T_28e58_row4_col3" class="data row4 col3" >87.78</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Read customer data
df2 = pd.read_csv('master_customer.csv')

# Merge transaction data (master_transaksi) and customer's data (master_customer)
df_areasales = pd.merge(df, df2, how='inner', on='custName')

# %%
df_areasales.head(5)
# Out:
#           orderID order_sent         custName  order_req type  productName  \
# 0  TRXINV1G1O0044 2016-01-05  A L F A - DEPOK 2016-01-05   DO      HWD-766
# 1  TRXINV1G1O0046 2016-01-05  A L F A - DEPOK 2016-01-05   DO   SK-P170-SL
# 2  TRXINV1G1O0046 2016-01-05  A L F A - DEPOK 2016-01-05   DO  SK-G256H-BK
# 3  TRXINV1G1O0046 2016-01-05  A L F A - DEPOK 2016-01-05   DO       SK-350
# 4  TRXINV1G1O0045 2016-01-05  A L F A - DEPOK 2016-01-05   DO    HWD-773SH
#
#    sales  perprice  qty  qty_req  purchase_year  customer_id  \
# 0  1HER2   1549000    5        5           2016            1
# 1  1HER2   1641000    2        2           2016            1
# 2  1HER2   3226000    2        2           2016            1
# 3  1HER2   4121000    2        2           2016            1
# 4  1HER2   1564000    5        5           2016            1
#
#                                        address     province
# 0  JL.PSR KEBAYORAN LAMA NO. 19 KEBAYORAN LAMA  DKI Jakarta
# 1  JL.PSR KEBAYORAN LAMA NO. 19 KEBAYORAN LAMA  DKI Jakarta
# 2  JL.PSR KEBAYORAN LAMA NO. 19 KEBAYORAN LAMA  DKI Jakarta
# 3  JL.PSR KEBAYORAN LAMA NO. 19 KEBAYORAN LAMA  DKI Jakarta
# 4  JL.PSR KEBAYORAN LAMA NO. 19 KEBAYORAN LAMA  DKI Jakarta

# %%
# Calculate totalprice for df_areasales
df_areasales['totalprice'] = df['qty'] * df['perprice']

# Annual summary grouped by province and year
yearly_region_summary = df_areasales.groupby(
    ['province', df_areasales['order_req'].dt.to_period('Y').rename('purchase_year')]
).agg(
    total_sales=('totalprice', 'sum'),
    avg_sales=('totalprice', 'mean'),
    total_orders=('orderID', 'count')
)

# Identify the top 5 provinces based on total sales
top_provinces = (
    yearly_region_summary.groupby('province')['total_sales']
    .sum()
    .nlargest(5)
    .index
)

# Filter for only the top 5 provinces
yearly_region_summary = yearly_region_summary.loc[yearly_region_summary.index.get_level_values('province').isin(top_provinces)]

# Calculate the growth rate for each metric within each region
yearly_region_summary['sales_growth_rate'] = yearly_region_summary.groupby('province')['total_sales'].pct_change() * 100
yearly_region_summary['aov_growth_rate'] = yearly_region_summary.groupby('province')['avg_sales'].pct_change() * 100
yearly_region_summary['order_growth_rate'] = yearly_region_summary.groupby('province')['total_orders'].pct_change() * 100

# Fill NaN values with 0 and round to 0 decimals
yearly_region_summary = yearly_region_summary.fillna(0).round(0)

# Apply background gradient and comma formatting
styled_yearly_region_summary = yearly_region_summary.style.format("{:,}").background_gradient(
    subset=['sales_growth_rate', 'aov_growth_rate', 'order_growth_rate'],
    cmap="RdYlGn",
    vmin=-100,
    vmax=100
)

# Display the styled yearly region summary
styled_yearly_region_summary
# Out:
# <style type="text/css">
# #T_8b137_row0_col3, #T_8b137_row0_col4, #T_8b137_row0_col5, #T_8b137_row5_col3, #T_8b137_row5_col4, #T_8b137_row5_col5, #T_8b137_row10_col3, #T_8b137_row10_col4, #T_8b137_row10_col5, #T_8b137_row15_col3, #T_8b137_row15_col4, #T_8b137_row15_col5, #T_8b137_row20_col3, #T_8b137_row20_col4, #T_8b137_row20_col5 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_8b137_row1_col3, #T_8b137_row1_col5, #T_8b137_row6_col3, #T_8b137_row6_col5, #T_8b137_row11_col5, #T_8b137_row18_col3, #T_8b137_row18_col5, #T_8b137_row19_col3, #T_8b137_row19_col5, #T_8b137_row21_col3, #T_8b137_row21_col5, #T_8b137_row23_col3, #T_8b137_row23_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_8b137_row1_col4 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_8b137_row2_col3 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_8b137_row2_col4 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_8b137_row2_col5 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_8b137_row3_col3 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_8b137_row3_col4 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_8b137_row3_col5 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_8b137_row4_col3, #T_8b137_row22_col5 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_8b137_row4_col4 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_8b137_row4_col5 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_8b137_row6_col4, #T_8b137_row12_col5, #T_8b137_row21_col4 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_8b137_row7_col3 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_8b137_row7_col4, #T_8b137_row18_col4 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_8b137_row7_col5 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_8b137_row8_col3, #T_8b137_row13_col5, #T_8b137_row24_col4 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_8b137_row8_col4 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_8b137_row8_col5, #T_8b137_row14_col5 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_8b137_row9_col3 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_8b137_row9_col4 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_8b137_row9_col5 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_8b137_row11_col3 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_8b137_row11_col4, #T_8b137_row13_col3 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_8b137_row12_col3 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_8b137_row12_col4 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_8b137_row13_col4 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_8b137_row14_col3 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_8b137_row14_col4, #T_8b137_row24_col3 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_8b137_row16_col3 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_8b137_row16_col4 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_8b137_row16_col5 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_8b137_row17_col3 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_8b137_row17_col4 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_8b137_row17_col5 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_8b137_row19_col4 {
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_8b137_row22_col3 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_8b137_row22_col4 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_8b137_row23_col4 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_8b137_row24_col5 {
#   background-color: #b3df72;
#   color: #000000;
# }
# </style>
# <table id="T_8b137">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b137_level0_col0" class="col_heading level0 col0" >total_sales</th>
#       <th id="T_8b137_level0_col1" class="col_heading level0 col1" >avg_sales</th>
#       <th id="T_8b137_level0_col2" class="col_heading level0 col2" >total_orders</th>
#       <th id="T_8b137_level0_col3" class="col_heading level0 col3" >sales_growth_rate</th>
#       <th id="T_8b137_level0_col4" class="col_heading level0 col4" >aov_growth_rate</th>
#       <th id="T_8b137_level0_col5" class="col_heading level0 col5" >order_growth_rate</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >province</th>
#       <th class="index_name level1" >purchase_year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b137_level0_row0" class="row_heading level0 row0" rowspan="5">Banten</th>
#       <th id="T_8b137_level1_row0" class="row_heading level1 row0" >2016</th>
#       <td id="T_8b137_row0_col0" class="data row0 col0" >2,155,608,640</td>
#       <td id="T_8b137_row0_col1" class="data row0 col1" >5,905,777.0</td>
#       <td id="T_8b137_row0_col2" class="data row0 col2" >365</td>
#       <td id="T_8b137_row0_col3" class="data row0 col3" >0.0</td>
#       <td id="T_8b137_row0_col4" class="data row0 col4" >0.0</td>
#       <td id="T_8b137_row0_col5" class="data row0 col5" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_8b137_level1_row1" class="row_heading level1 row1" >2017</th>
#       <td id="T_8b137_row1_col0" class="data row1 col0" >7,234,711,606</td>
#       <td id="T_8b137_row1_col1" class="data row1 col1" >4,807,117.0</td>
#       <td id="T_8b137_row1_col2" class="data row1 col2" >1,505</td>
#       <td id="T_8b137_row1_col3" class="data row1 col3" >236.0</td>
#       <td id="T_8b137_row1_col4" class="data row1 col4" >-19.0</td>
#       <td id="T_8b137_row1_col5" class="data row1 col5" >312.0</td>
#     </tr>
#     <tr>
#       <th id="T_8b137_level1_row2" class="row_heading level1 row2" >2018</th>
#       <td id="T_8b137_row2_col0" class="data row2 col0" >6,910,249,376</td>
#       <td id="T_8b137_row2_col1" class="data row2 col1" >5,744,181.0</td>
#       <td id="T_8b137_row2_col2" class="data row2 col2" >1,203</td>
#       <td id="T_8b137_row2_col3" class="data row2 col3" >-4.0</td>
#       <td id="T_8b137_row2_col4" class="data row2 col4" >19.0</td>
#       <td id="T_8b137_row2_col5" class="data row2 col5" >-20.0</td>
#     </tr>
#     <tr>
#       <th id="T_8b137_level1_row3" class="row_heading level1 row3" >2019</th>
#       <td id="T_8b137_row3_col0" class="data row3 col0" >6,854,232,198</td>
#       <td id="T_8b137_row3_col1" class="data row3 col1" >5,329,885.0</td>
#       <td id="T_8b137_row3_col2" class="data row3 col2" >1,286</td>
#       <td id="T_8b137_row3_col3" class="data row3 col3" >-1.0</td>
#       <td id="T_8b137_row3_col4" class="data row3 col4" >-7.0</td>
#       <td id="T_8b137_row3_col5" class="data row3 col5" >7.0</td>
#     </tr>
#     <tr>
#       <th id="T_8b137_level1_row4" class="row_heading level1 row4" >2020</th>
#       <td id="T_8b137_row4_col0" class="data row4 col0" >5,394,998,027</td>
#       <td id="T_8b137_row4_col1" class="data row4 col1" >5,493,888.0</td>
#       <td id="T_8b137_row4_col2" class="data row4 col2" >982</td>
#       <td id="T_8b137_row4_col3" class="data row4 col3" >-21.0</td>
#       <td id="T_8b137_row4_col4" class="data row4 col4" >3.0</td>
#       <td id="T_8b137_row4_col5" class="data row4 col5" >-24.0</td>
#     </tr>
#     <tr>
#       <th id="T_8b137_level0_row5" class="row_heading level0 row5" rowspan="5">DKI Jakarta</th>
#       <th id="T_8b137_level1_row5" class="row_heading level1 row5" >2016</th>
#       <td id="T_8b137_row5_col0" class="data row5 col0" >2,496,745,856</td>
#       <td id="T_8b137_row5_col1" class="data row5 col1" >6,060,063.0</td>
#       <td id="T_8b137_row5_col2" class="data row5 col2" >412</td>
#       <td id="T_8b137_row5_col3" class="data row5 col3" >0.0</td>
#       <td id="T_8b137_row5_col4" class="data row5 col4" >0.0</td>
#       <td id="T_8b137_row5_col5" class="data row5 col5" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_8b137_level1_row6" class="row_heading level1 row6" >2017</th>

# %%
# Group by 'region' and 'month' to calculate monthly total sales
monthly_sales = df_areasales.groupby(
    [df_areasales['order_req'].dt.to_period('M'), 'province']
)['totalprice'].sum().unstack(fill_value=0)

# Identify the top 5 regions based on total sales
top_regions = monthly_sales.sum(axis=0).nlargest(5).index

# Filter the data to include only the top 5 regions
monthly_sales_top = monthly_sales[top_regions]

# Sort the columns (regions) by total sales in descending order for proper stacking
monthly_sales_top = monthly_sales_top[top_regions[::-1]]

# Normalize to get the percentage contribution of each region per month
monthly_sales_percent_top = monthly_sales_top.div(monthly_sales_top.sum(axis=1), axis=0) * 100

# Define a function to plot stacked area charts with yearly markers and yearly x-axis labels
def plot_stacked_area(data, title, ylabel):
    plt.figure(figsize=(10, 6))
    plt.stackplot(data.index.astype(str), data.T, labels=data.columns)

    # Add vertical lines at the start of each year
    years = sorted(data.index.year.unique())
    for year in years:
        plt.axvline(x=f'{year}-01', color='black', linestyle=':', linewidth=0.5)

    # Reverse legend order to match stacking
    handles, labels = plt.gca().get_legend_handles_labels()
    plt.legend(handles[::-1], labels[::-1], loc='upper left', title='Region')

    # Set titles and labels
    plt.title(title)
    plt.xlabel('Year')
    plt.ylabel(ylabel)

    # Show only years on the x-axis labels
    plt.xticks([f"{year}-01" for year in years], [str(year) for year in years])

    plt.tight_layout()
    plt.show()

# Plot the total sales stacked area chart for the top 5 regions
plot_stacked_area(
    monthly_sales_top,
    title='Total Monthly Sales by Top 5 Provinces (Rupiah)',
    ylabel='Total Monthly Sales (Rupiah Millions)'
)
